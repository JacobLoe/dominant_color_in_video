# %%
import numpy as np

# %%
i=[[[0,1,2],[3,4,5]],[[7,8,9],[10,11,12]]]
print(i)
# i=np.array(i)
sh=np.array([i,i,i]) #shot with 3 im
sc=[sh,sh,sh,sh,sh] #scene with 5 shots
# print(np.shape(sc))
# print(sc[0])
# print(sc[0].reshape((np.shape(sc)[1]*np.shape(sc)[2]*np.shape(sc)[3],3)))
# print(sc)
with open('test.txt','w') as t:
    print(np.shape(sc),file=t)
    for shot in sc:
        shot = shot.reshape((np.shape(sc)[1]*np.shape(sc)[2]*np.shape(sc)[3],3))
        shot_aux=[list(s) for s in shot]
#         print(shot_aux)
#         print(shot)
#         print(shot_aux,file=t)
#         break
#         print(';',file=t)
# Out:
# [[[0, 1, 2], [3, 4, 5]], [[7, 8, 9], [10, 11, 12]]]

# %%
print(type(np.shape(sc)))
print(np.shape(sc))
print(type(sc))
print(sc)
# Out:
# <class 'tuple'>
# (5, 3, 2, 2, 3)
# <class 'list'>
# [array([[[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]]]), array([[[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]]]), array([[[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
# ...

# %%
stuff=[]
with open('test.txt','r') as t:
    for i,line in enumerate(t):
        if i==0:
            shape=line.strip().strip(')').strip('(').split(",")
            shape=[int(num.strip()) for num in shape]
        else:
            line=line.split('], [')
            line_aux=[frame.strip().strip('[').strip(']') for frame in line]
            line_aux=[frame.strip().split(',') for frame in line_aux]
            line_aux=np.array(line_aux,dtype='uint8')
            
            line_aux=line_aux.reshape(shape[1:])
            
            stuff.append(line_aux)
    print(type(stuff))
    print(np.shape(stuff))
    print(stuff)
# Out:
# <class 'list'>
# (5, 3, 2, 2, 3)
# [array([[[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]]], dtype=uint8), array([[[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]]], dtype=uint8), array([[[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
#         [[ 7,  8,  9],
#          [10, 11, 12]]],
#
#
#        [[[ 0,  1,  2],
#          [ 3,  4,  5]],
#
# ...

# %%
for a,b in zip(stuff,sc):
    assert a.all()==b.all()
